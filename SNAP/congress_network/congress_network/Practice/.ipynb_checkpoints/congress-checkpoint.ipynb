# %%
import os
import pandas as pd
import numpy as np
import json
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
last_dir  =os.path.dirname(os.getcwd())
with open(last_dir+"\\congress_network_data.json") as f:
    json_net = f.read()
net = json.loads(json_net)
net = net[0]

# %%
index_dict = dict(zip(net["usernameList"], range(len(net["usernameList"]))))
index_dict
# Out:
# {'SenatorBaldwin': 0,
#  'SenJohnBarrasso': 1,
#  'SenatorBennet': 2,
#  'MarshaBlackburn': 3,
#  'SenBlumenthal': 4,
#  'RoyBlunt': 5,
#  'CoryBooker': 6,
#  'JohnBoozman': 7,
#  'SenatorBraun': 8,
#  'SenSherrodBrown': 9,
#  'SenatorCantwell': 10,
#  'SenCapito': 11,
#  'SenatorCardin': 12,
#  'SenatorCarper': 13,
#  'SenBobCasey': 14,
#  'SenBillCassidy': 15,
#  'ChrisCoons': 16,
#  'JohnCornyn': 17,
#  'SenCortezMasto': 18,
#  'SenTomCotton': 19,
#  'SenKevinCramer': 20,
#  'MikeCrapo': 21,
#  'SenTedCruz': 22,
#  'SteveDaines': 23,
#  'SenDuckworth': 24,
#  'SenatorDurbin': 25,
#  'SenJoniErnst': 26,
#  'SenFeinstein': 27,
#  'SenatorFischer': 28,
#  'SenGillibrand': 29,
#  'LindseyGrahamSC': 30,
#  'ChuckGrassley': 31,
#  'SenatorHagerty': 32,
#  'SenatorHassan': 33,
#  'HawleyMO': 34,
#  'MartinHeinrich': 35,
#  'SenatorHick': 36,
#  'maziehirono': 37,
#  'SenJohnHoeven': 38,
#  'SenHydeSmith': 39,
#  'JimInhofe': 40,
#  'SenRonJohnson': 41,
#  'timkaine': 42,
#  'SenMarkKelly': 43,
#  'SenJohnKennedy': 44,
#  'SenAngusKing': 45,
#  'SenAmyKlobuchar': 46,
#  'SenatorLankford': 47,
#  'SenatorLeahy': 48,
#  'SenMikeLee': 49,
#  'SenatorLujan': 50,
#  'SenLummis': 51,
#  'Sen_JoeManchin': 52,
#  'SenMarkey': 53,
#  'SenatorMenendez': 54,
#  'SenJeffMerkley': 55,
#  'JerryMoran': 56,
#  'lisamurkowski': 57,
#  'ChrisMurphyCT': 58,
#  'PattyMurray': 59,
#  'ossoff': 60,
#  'SenAlexPadilla': 61,
#  'RandPaul': 62,
#  'SenGaryPeters': 63,
#  'senrobportman': 64,
#  'SenJackReed': 65,
#  'SenatorRisch': 66,
#  'SenatorRomney': 67,
#  'SenJackyRosen': 68,
#  'marcorubio': 69,
#  'SenSanders': 70,
#  'SenSchumer': 71,
#  'SenRickScott': 72,
#  'SenatorTimScott': 73,
#  'SenatorShaheen': 74,
#  'SenatorSinema': 75,
#  'SenTinaSmith': 76,
#  'SenStabenow': 77,
#  'SenDanSullivan': 78,
#  'SenatorTester': 79,
#  'SenJohnThune': 80,
#  'SenThomTillis': 81,
#  'SenToomey': 82,
#  'SenTuberville': 83,
#  'ChrisVanHollen': 84,
#  'MarkWarner': 85,
#  'SenatorWarnock': 86,
#  'SenWarren': 87,
#  'SenWhitehouse': 88,
#  'SenatorWicker': 89,
#  'RonWyden': 90,
#  'SenToddYoung': 91,
#  'RepAdams': 92,
#  'Robert_Aderholt': 93,
#  'RepPeteAguilar': 94,
#  'RepRickAllen': 95,
#  'RepColinAllred': 96,
#  'RepArmstrongND': 97,
#  'RepArrington': 98,
#  'RepAuchincloss': 99,
#  'RepCindyAxne': 100,
#  'RepBrianBabin': 101,
#  'RepDonBacon': 102,
#  'RepJimBaird': 103,
#  'RepBalderson': 104,
#  'RepJimBanks': 105,
#  'RepAndyBarr': 106,
#  'RepBarragan': 107,
#  'RepKarenBass': 108,
#  'RepBeatty': 109,
#  'RepBera': 110,
#  'RepDonBeyer': 111,
#  'RepBice': 112,
#  'RepAndyBiggsAZ': 113,
#  'RepGusBilirakis': 114,
#  'SanfordBishop': 115,
#  'RepDanBishop': 116,
#  'RepLBR': 117,
#  'RepBoebert': 118,
#  'RepBonamici': 119,
#  'RepBost': 120,
#  'RepBourdeaux': 121,
#  'RepBowman': 122,
#  'CongBoyle': 123,
#  'RepKevinBrady': 124,
#  'RepMoBrooks': 125,
#  'RepAnthonyBrown': 126,
#  'RepShontelBrown': 127,
#  'RepBrownley': 128,
#  'VernBuchanan': 129,
#  'RepKenBuck': 130,
#  'RepLarryBucshon': 131,
#  'RepTedBudd': 132,
#  'RepTimBurchett': 133,
#  'michaelcburgess': 134,
#  'RepCori': 135,
#  'RepCheri': 136,
#  'RepKatCammack': 137,
#  'RepCarbajal': 138,
#  'RepCardenas': 139,
#  'RepMikeCarey': 140,
#  'RepJerryCarl': 141,
#  'RepAndreCarson': 142,
#  'RepBuddyCarter': 143,
#  'JudgeCarter': 144,
#  'RepTroyCarter': 145,
#  'RepEdCase': 146,
#  'RepCasten': 147,
#  'USRepKCastor': 148,
#  'JoaquinCastrotx': 149,
#  'RepCawthorn': 150,
#  'RepSteveChabot': 151,
#  'RepLizCheney': 152,
#  'CongresswomanSC': 153,
#  'RepJudyChu': 154,
#  'RepKClark': 155,
#  'RepYvetteClarke': 156,
#  'repcleaver': 157,
#  'RepBenCline': 158,
#  'RepCloudTX': 159,
#  'WhipClyburn': 160,
#  'Rep_Clyde': 161,
#  'RepCohen': 162,
#  'TomColeOK04': 163,
#  'RepJamesComer': 164,
#  'GerryConnolly': 165,
#  'RepLouCorrea': 166,
#  'RepJimCosta': 167,
#  'RepJoeCourtney': 168,
#  'RepAngieCraig': 169,
#  'RepCharlieCrist': 170,
#  'RepJasonCrow': 171,
#  'RepJohnCurtis': 172,
#  'RepDavids': 173,
#  'WarrenDavidson': 174,
#  'RodneyDavis': 175,
#  'RepDean': 176,
#  'RepPeterDeFazio': 177,
#  'RepDianaDeGette': 178,
#  'rosadelauro': 179,
#  'RepDelBene': 180,
#  'repdelgado': 181,
#  'RepValDemings': 182,
#  'RepDeSaulnier': 183,
#  'RepTedDeutch': 184,
#  'MarioDB': 185,
#  'RepDebDingell': 186,
#  'RepLloydDoggett': 187,
#  'RepDonaldsPress': 188,
#  'USRepMikeDoyle': 189,
#  'RepJeffDuncan': 190,
#  'DrNealDunnFL2': 191,
#  'RepTomEmmer': 192,
#  'RepEscobar': 193,
#  'RepAnnaEshoo': 194,
#  'RepEspaillat': 195,
#  'RepRonEstes': 196,
#  'RepDwightEvans': 197,
#  'RepPatFallon': 198,
#  'RepFeenstra': 199,
#  'RepDrewFerguson': 200,
#  'RepFischbach': 201,
#  'RepBrianFitz': 202,
#  'RepChuck': 203,
#  'RepFletcher': 204,
#  'RepBillFoster': 205,
#  'virginiafoxx': 206,
#  'RepLoisFrankel': 207,
#  'RepFranklin': 208,
#  'RepRussFulcher': 209,
#  'RepMattGaetz': 210,
#  'RepGallagher': 211,
#  'RepRubenGallego': 212,
#  'RepGaramendi': 213,
#  'RepGarbarino': 214,
#  'RepChuyGarcia': 215,
#  'RepMikeGarcia': 216,
#  'RepSylviaGarcia': 217,
#  'RepBobGibbs': 218,
#  'RepCarlos': 219,
#  'replouiegohmert': 220,
#  'RepGolden': 221,
#  'RepJimmyGomez': 222,
#  'RepTonyGonzales': 223,
#  'RepJenniffer': 224,
#  'RepGonzalez': 225,
#  'RepBobGood': 226,
#  'Lancegooden': 227,
#  'RepGosar': 228,
#  'RepJoshG': 229,
#  'RepKayGranger': 230,
#  'RepGarretGraves': 231,
#  'RepAlGreen': 232,
#  'RepMarkGreen': 233,
#  'RepMTG': 234,
#  'RepMGriffith': 235,
#  'RepRaulGrijalva': 236,
#  'RepGrothman': 237,
#  'RepMichaelGuest': 238,
#  'RepGuthrie': 239,
#  'RepJoshHarder': 240,
#  'RepHarshbarger': 241,
#  'RepHartzler': 242,
#  'RepJahanaHayes': 243,
#  'repkevinhern': 244,
#  'RepHerrell': 245,
#  'CongressmanHice': 246,
#  'RepBrianHiggins': 247,
#  'RepClayHiggins': 248,
#  'RepFrenchHill': 249,
#  'jahimes': 250,
#  'RepAshleyHinson': 251,
#  'RepHorsford': 252,
#  'RepHoulahan': 253,
#  'LeaderHoyer': 254,
#  'RepRichHudson': 255,
#  'RepHuffman': 256,
#  'RepHuizenga': 257,
#  'repdarrellissa': 258,
#  'JacksonLeeTX18': 259,
#  'RepRonnyJackson': 260,
#  'RepJacobs': 261,
#  'RepSaraJacobs': 262,
#  'RepJayapal': 263,
#  'RepJeffries': 264,
#  'RepBillJohnson': 265,
#  'RepDustyJohnson': 266,
#  'RepEBJ': 267,
#  'RepHankJohnson': 268,
#  'RepMikeJohnson': 269,
#  'RepMondaire': 270,
#  'Jim_Jordan': 271,
#  'RepDaveJoyce': 272,
#  'RepJohnJoyce': 273,
#  'RepJohnKatko': 274,
#  'USRepKeating': 275,
#  'RepFredKeller': 276,
#  'MikeKellyPA': 277,
#  'RepRobinKelly': 278,
#  'RepRoKhanna': 279,
#  'RepDanKildee': 280,
#  'RepDerekKilmer': 281,
#  'RepAndyKimNJ': 282,
#  'RepYoungKim': 283,
#  'RepRonKind': 284,
#  'RepKirkpatrick': 285,
#  'CongressmanRaja': 286,
#  'RepAnnieKuster': 287,
#  'RepDavidKustoff': 288,
#  'RepLaHood': 289,
#  'RepLaMalfa': 290,
#  'JimLangevin': 291,
#  'RepRickLarsen': 292,
#  'RepJohnLarson': 293,
#  'boblatta': 294,
#  'RepLaTurner': 295,
#  'RepLawrence': 296,
#  'RepAlLawsonJr': 297,
#  'RepBarbaraLee': 298,
#  'RepSusieLee': 299,
#  'RepTeresaLF': 300,
#  'RepDLesko': 301,
#  'RepJuliaLetlow': 302,
#  'RepAndyLevin': 303,
#  'RepMikeLevin': 304,
#  'RepTedLieu': 305,
#  'USRepLong': 306,
#  'RepLoudermilk': 307,
#  'RepLowenthal': 308,
#  'RepFrankLucas': 309,
#  'RepBlaine': 310,
#  'RepElaineLuria': 311,
#  'RepNancyMace': 312,
#  'RepMalinowski': 313,
#  'RepMalliotakis': 314,
#  'RepMaloney': 315,
#  'RepSeanMaloney': 316,
#  'RepKManning': 317,
#  'RepThomasMassie': 318,
#  'RepBrianMast': 319,
#  'DorisMatsui': 320,
#  'RepLucyMcBath': 321,
#  'GOPLeader': 322,
#  'RepMcCaul': 323,
#  'RepLisaMcClain': 324,
#  'BettyMcCollum04': 325,
#  'RepMcEachin': 326,
#  'RepMcGovern': 327,
#  'PatrickMcHenry': 328,
#  'RepMcKinley': 329,
#  'RepGregoryMeeks': 330,
#  'RepMeijer': 331,
#  'RepGraceMeng': 332,
#  'RepMeuser': 333,
#  'RepKweisiMfume': 334,
#  'RepMMM': 335,
#  'RepCarolMiller': 336,
#  'RepMaryMiller': 337,
#  'RepAlexMooney': 338,
#  'RepBarryMoore': 339,
#  'RepBlakeMoore': 340,
#  'RepGwenMoore': 341,
#  'RepJoeMorelle': 342,
#  'RepMullin': 343,
#  'RepGregMurphy': 344,
#  'RepStephMurphy': 345,
#  'RepJerryNadler': 346,
#  'gracenapolitano': 347,
#  'RepRichardNeal': 348,
#  'RepJoeNeguse': 349,
#  'RepTroyNehls': 350,
#  'RepNewhouse': 351,
#  'RepMarieNewman': 352,
#  'DonaldNorcross': 353,
#  'RepRalphNorman': 354,
#  'EleanorNorton': 355,
#  'RepOHalleran': 356,
#  'JayObernolte': 357,
#  'Ilhan': 358,
#  'RepBurgessOwens': 359,
#  'CongPalazzo': 360,
#  'FrankPallone': 361,
#  'USRepGaryPalmer': 362,
#  'RepJimmyPanetta': 363,
#  'RepChrisPappas': 364,
#  'BillPascrell': 365,
#  'RepDonaldPayne': 366,
#  'SpeakerPelosi': 367,
#  'RepPerlmutter': 368,
#  'RepScottPeters': 369,
#  'RepPfluger': 370,
#  'RepDeanPhillips': 371,
#  'chelliepingree': 372,
#  'StaceyPlaskett': 373,
#  'repmarkpocan': 374,
#  'RepKatiePorter': 375,
#  'RepPressley': 376,
#  'RepDavidEPrice': 377,
#  'RepMikeQuigley': 378,
#  'RepRaskin': 379,
#  'GReschenthaler': 380,
#  'RepKathleenRice': 381,
#  'RepTomRice': 382,
#  'cathymcmorris': 383,
#  'RepMikeRogersAL': 384,
#  'RepJohnRose': 385,
#  'RepRosendale': 386,
#  'RepDeborahRoss': 387,
#  'RepDavidRouzer': 388,
#  'RepChipRoy': 389,
#  'RepRoybalAllard': 390,
#  'RepRaulRuizMD': 391,
#  'Call_Me_Dutch': 392,
#  'RepBobbyRush': 393,
#  'RepTimRyan': 394,
#  'Kilili_Sablan': 395,
#  'RepMariaSalazar': 396,
#  'RepLindaSanchez': 397,
#  'RepSarbanes': 398,
#  'SteveScalise': 399,
#  'RepMGS': 400,
#  'janschakowsky': 401,
#  'RepAdamSchiff': 402,
#  'RepSchneider': 403,
#  'RepSchrader': 404,
#  'RepKimSchrier': 405,
#  'RepDavid': 406,
#  'AustinScottGA08': 407,
#  'BobbyScott': 408,
#  'PeteSessions': 409,
#  'RepTerriSewell': 410,
#  'BradSherman': 411,
#  'RepSherrill': 412,
#  'CongMikeSimpson': 413,
#  'RepSires': 414,
#  'RepSlotkin': 415,
#  'RepAdamSmith': 416,
#  'RepAdrianSmith': 417,
#  'RepJasonSmith': 418,
#  'RepSmucker': 419,
#  'RepDarrenSoto': 420,
#  'RepSpanberger': 421,
#  'RepSpartz': 422,
#  'RepSpeier': 423,
#  'Rep_Stansbury': 424,
#  'RepGregStanton': 425,
#  'RepPeteStauber': 426,
#  'RepSteel': 427,
#  'RepStefanik': 428,
#  'RepBryanSteil': 429,
#  'RepGregSteube': 430,
#  'RepHaleyStevens': 431,
#  'RepChrisStewart': 432,
#  'RepStricklandWA': 433,
#  'RepTomSuozzi': 434,
#  'RepSwalwell': 435,
#  'RepMarkTakano': 436,
#  'claudiatenney': 437,
#  'BennieGThompson': 438,
#  'RepThompson': 439,
#  'RepTiffany': 440,
#  'RepTimmons': 441,
#  'repdinatitus': 442,
#  'RepRashida': 443,
#  'RepPaulTonko': 444,
#  'NormaJTorres': 445,
#  'RepRitchie': 446,
#  'RepLoriTrahan': 447,
#  'RepDavidTrone': 448,
#  'RepMikeTurner': 449,
#  'RepUnderwood': 450,
#  'RepDavidValadao': 451,
#  'RepBethVanDuyne': 452,
#  'RepJuanVargas': 453,
#  'RepVeasey': 454,
#  'NydiaVelazquez': 455,
#  'RepAnnWagner': 456,
#  'RepWalberg': 457,
#  'RepWalorski': 458,
#  'michaelgwaltz': 459,
#  'RepDWStweets': 460,
#  'RepBonnie': 461,
#  'RepWebster': 462,
#  'PeterWelch': 463,
#  'RepWesterman': 464,
#  'RepWexton': 465,
#  'RepSusanWild': 466,
#  'RepNikema': 467,
#  'RepRWilliams': 468,
#  'RepWilson': 469,
#  'RepJoeWilson': 470,
#  'RobWittman': 471,
#  'rep_stevewomack': 472,
#  'RepJohnYarmuth': 473,
#  'RepLeeZeldin': 474}

# %%
dg = nx.DiGraph()
dg.add_nodes_from(range(len(net["usernameList"])))

for i, nodes in enumerate(net["inList"]):
    dg.add_edges_from((node, i) for node in nodes)
    
len(dg.nodes), len(dg.edges)
# Out:
# (475, 13289)

# %%
plt.figure(figsize=(20, 20))  # 调整图形大小
pos = nx.spring_layout(dg)  # 使用弹簧布局（常用于减少拥挤）
nx.draw(dg, pos, with_labels=True, font_size=10)
plt.savefig("congress.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
#  284: 0.0007759295696783831,
#  285: 0.0006907274839311334,
#  286: 0.0027181732193549213,
#  287: 0.0013239480061990752,
#  288: 0.0013358732712934135,
#  289: 0.00117481954772138,
#  290: 0.0019458764473220262,
#  291: 0.00159587805009244,
#  292: 0.004573572571921423,
#  293: 0.002242226856040119,
#  294: 0.0016720160375852688,
#  295: 0.0016508508559500523,
#  296: 0.0024041357655214647,
#  297: 0.0004488430716471113,
#  298: 0.002917418655305071,
#  299: 0.002793837374124033,
#  300: 0.0012088200413037757,
#  301: 0.004488220633802728,
#  302: 0.001172381960166416,
#  303: 0.007362140150506992,
#  304: 0.001146910255944824,
#  305: 0.0030495969811481006,
#  306: 0.0016314882809750453,
#  307: 0.0007748414199513268,
#  308: 0.000773839983878178,
#  309: 0.0012231150265818451,
#  310: 0.0011777107205102097,
#  311: 0.0011043231034850534,
#  312: 0.002446476450719941,
#  313: 0.0022593415226297843,
#  314: 0.001261845801004227,
#  315: 0.004489748673542211,
#  316: 0.000534132395683129,
#  317: 0.001541432096788478,
#  318: 0.005225114573102854,
#  319: 0.0014012815548713358,
#  320: 0.0013376211463690837,
#  321: 0.0004826708463167926,
#  322: 0.00931386275435248,
#  323: 0.0013228719821762633,
#  324: 0.0059130301345418175,
#  325: 0.003001453790934778,
#  326: 0.0020971223190693173,
#  327: 0.0029741798695248397,
#  328: 0.0007314954883855076,
#  329: 0.001064709272392652,
#  330: 0.0016033833173825234,
#  331: 0.0018146553168565832,
#  332: 0.0023719400590435803,
#  333: 0.0008561905203050123,
#  334: 0.0009755046807758387,
#  335: 0.006361271853273359,
#  336: 0.0020849015383096136,
#  337: 0.0007052791799679454,
#  338: 0.0022085412948900543,
#  339: 0.00280101219564051,
#  340: 0.0015549303388158082,
#  341: 0.003114091404367075,
#  342: 0.0008295084490185308,
#  343: 0.004176680885983796,
#  344: 0.0018245580602356008,
#  345: 0.0013912226906533831,
#  346: 0.002886204249604269,
#  347: 0.0022160820592591235,
#  348: 0.0006034664179846675,
#  349: 0.0026447653647645097,
#  350: 0.005867055333411399,
#  351: 0.002339953545257247,
#  352: 0.0020527980876725656,
#  353: 0.001720513805142172,
#  354: 0.0038679406506150087,
#  355: 0.0017067745867432949,
#  356: 0.0003157894736842106,
#  357: 0.0011044362796852022,
#  358: 0.002107553533572144,
#  359: 0.001418691635285282,
#  360: 0.0015870868303044516,
#  361: 0.000674440384879623,
#  362: 0.0012561534154451111,
#  363: 0.0006464113011756774,
#  364: 0.0008881510274428988,
#  365: 0.0021306244785853326,
#  366: 0.0005168819963532055,
#  367: 0.0031151657403353365,
#  368: 0.0025828264499956487,
#  369: 0.0013854702430376384,
#  370: 0.003377080552678386,
#  371: 0.0036731884331630184,
#  372: 0.002054773093901287,
#  373: 0.0019305617665498682,
#  374: 0.0032055672087871064,
#  375: 0.0016387834649397152,
#  376: 0.0036732400165458254,
#  377: 0.0015698134882491167,
#  378: 0.002090505314386102,
#  379: 0.001635890024463506,
#  380: 0.0025186506478917536,
#  381: 0.001439136528456641,
#  382: 0.006263789388269624,
#  383: 0.0028305943108543653,
#  384: 0.0013124437608793564,
#  385: 0.00844090528824954,
#  386: 0.006070686070204337,
#  387: 0.0027489736902686092,
#  388: 0.0009593828880149019,
#  389: 0.006260172582266629,
#  390: 0.0013573399477162448,
#  391: 0.0013289234122376005,
#  392: 0.001933958073127906,
#  393: 0.006797873617893634,
#  394: 0.0017870868737080545,
#  395: 0.00032956074661780974,
#  396: 0.0014652055849312647,
#  397: 0.0010893629534284317,
#  398: 0.0015853328186647827,
#  399: 0.005185512529919825,
#  400: 0.004908175781539949,
#  401: 0.005086828970033723,
#  402: 0.0007413659059143062,
#  403: 0.0008920859424733214,
#  404: 0.0006152787645184774,
#  405: 0.0012342790015299327,
#  406: 0.0024933620285277833,
#  407: 0.0012636493537337358,
#  408: 0.002308234899942548,
#  409: 0.0026273411064198482,
#  410: 0.0011748790347467719,
#  411: 0.0009141847611577135,
#  412: 0.0009607601535567025,
#  413: 0.0005266592957410068,
#  414: 0.0010340861784101285,
#  415: 0.0009411044326891512,
#  416: 0.00323950517882906,
#  417: 0.005145443357391833,
#  418: 0.0016821573019401358,
#  419: 0.0008906597331331698,
#  420: 0.0034181648245984343,
#  421: 0.003425750919294466,
#  422: 0.000734747333811544,
#  423: 0.0025823977366647493,
#  424: 0.0038628021404388873,
#  425: 0.0007389640817560355,
#  426: 0.002223055584828783,
#  427: 0.0022619906496214454,
#  428: 0.00524997550028898,
#  429: 0.0009513545564796732,
#  430: 0.001295566281282791,
#  431: 0.003742650611388058,
#  432: 0.0010173150346104631,
#  433: 0.001663012501232668,
#  434: 0.0003157894736842106,
#  435: 0.0028533529190161904,
#  436: 0.0007465906723969917,
#  437: 0.002537315663632676,
#  438: 0.0011701172978970768,
#  439: 0.002530410479778799,
#  440: 0.0027371754598269804,
#  441: 0.0024065214387471,
#  442: 0.003367935701053725,
#  443: 0.0022845989539714293,
#  444: 0.0007364742405533237,
#  445: 0.0018805891233871145,
#  446: 0.0039390406615434975,
#  447: 0.0018208544378043637,
#  448: 0.0025696174042991082,
#  449: 0.0013124271030998534,
#  450: 0.0021288957155895893,
#  451: 0.0012358622612326955,
#  452: 0.00470531148098752,
#  453: 0.002040866093299621,
#  454: 0.0013537887535596304,
#  455: 0.00112328285229454,
#  456: 0.0003157894736842106,
#  457: 0.0007012704648609971,
#  458: 0.0005924728780560111,
#  459: 0.0013742228437979313,
#  460: 0.003145590079450485,
#  461: 0.0054209411174032844,
#  462: 0.0016535688207646917,
#  463: 0.0009405888398983452,
#  464: 0.0030286313054011045,
#  465: 0.0016340805393978584,
#  466: 0.0016106848506048832,
#  467: 0.002653998292697094,
#  468: 0.0014640357365440573,
#  469: 0.003004000806149964,
#  470: 0.0017799837191244533,
#  471: 0.0010167977898977879,
#  472: 0.0026333580647476098,
#  473: 0.000554623134388195,
#  474: 0.0005110421517461657}

# %%
plt.figure(figsize=(20, 20))
plt.bar(pagerank.keys(), pagerank.values())
plt.show()
